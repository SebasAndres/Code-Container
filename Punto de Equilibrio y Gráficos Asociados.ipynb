# %%
import matplotlib.pyplot as plt

oferta = lambda x: x**2 + x + 2
demanda = lambda x: -x + 200 

x = [n for n in range(20)]
plt.plot(x, [demanda(n) for n in x], label="...")

plt.xlabel("Cantidad");
plt.ylabel("Precio");

plt.legend()
plt.show()
